# %% [markdown]
# <a href="https://colab.research.google.com/github/dukyoon13/Python/blob/main/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(len('name'))
print(len('number'))
print(len(['name']))
print(len(['name', 'number']))
# Out:
# 4
# 6
# 1
# 2

# %%
nums1 = [1, 20, 300]
nums2 = [1, 20.0, 300]
print(sum(nums1))
print(sum(nums2))
# Out:
# 321
# 321.0

# %%
nums = [30, 4, 50, 6]
print(max(nums))
print(min(nums))
# Out:
# 50
# 4

# %%
words = ['monkey', 'ape', 'gorilla']
print(max(words))
print(min(words))
# Out:
# monkey
# ape

# %%
nums = [30, 4, 50, 6]
print(sorted(nums))
words = ['monkey', 'ape', 'gorilla']
print(sorted(words))
print(sorted(words, reverse=True))
# Out:
# [4, 6, 30, 50]
# ['ape', 'gorilla', 'monkey']
# ['monkey', 'gorilla', 'ape']
